# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mds=pd.read_csv('embedding_output.csv')
onehot=pd.read_csv('onehot_output.csv')

# %%
plt.plot(range(len(mds['Sum of pairs'][100:200])), mds['Sum of pairs'][100:200].tolist(), color='r')
plt.ylim((-5000, 5000))
# Out:
# (-5000.0, 5000.0)

# %%
plt.plot(range(len(onehot['Sum of pairs'][100:200])), onehot['Sum of pairs'][100:200].tolist(), color='b')
plt.ylim((-5000, 5000))
# Out:
# (-5000.0, 5000.0)

# %%
plt.plot(range(len(mds['Sum of pairs'])), mds['Sum of pairs'].tolist(), color='r')
plt.plot(range(len(onehot['Sum of pairs'])), onehot['Sum of pairs'].tolist(), color='b')
plt.ylim((-5000, 5000))
# Out:
# (-5000.0, 5000.0)
